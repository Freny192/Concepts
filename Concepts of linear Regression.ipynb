# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
import os

# %%
folder_path = 'C:/Users/fpate/Desktop/AIT-580'
os.chdir(folder_path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\fpate\\Desktop\\AIT-580'

# %%
data = pd.read_csv('co2_annmean_gl.csv')

# %%
data
# Out:
#     year    mean   unc
# 0   1979  336.85  0.10
# 1   1980  338.91  0.07
# 2   1981  340.11  0.08
# 3   1982  340.86  0.03
# 4   1983  342.53  0.05
# 5   1984  344.07  0.07
# 6   1985  345.54  0.07
# 7   1986  346.97  0.07
# 8   1987  348.68  0.09
# 9   1988  351.16  0.07
# 10  1989  352.78  0.06
# 11  1990  354.05  0.07
# 12  1991  355.39  0.06
# 13  1992  356.09  0.06
# 14  1993  356.83  0.07
# 15  1994  358.33  0.07
# 16  1995  360.17  0.05
# 17  1996  361.93  0.04
# 18  1997  363.05  0.05
# 19  1998  365.70  0.04
# 20  1999  367.80  0.07
# 21  2000  368.96  0.06
# 22  2001  370.57  0.05
# 23  2002  372.59  0.04
# 24  2003  375.15  0.04
# 25  2004  376.95  0.06
# 26  2005  378.98  0.05
# 27  2006  381.15  0.05
# 28  2007  382.90  0.05
# 29  2008  385.02  0.05
# 30  2009  386.50  0.04
# 31  2010  388.76  0.06
# 32  2011  390.63  0.06
# 33  2012  392.65  0.07
# 34  2013  395.40  0.06
# 35  2014  397.34  0.05
# 36  2015  399.65  0.05
# 37  2016  403.06  0.07
# 38  2017  405.22  0.07
# ...

# %%
data1 = data.iloc[1:]

# %%
data1
# Out:
#     year    mean   unc
# 1   1980  338.91  0.07
# 2   1981  340.11  0.08
# 3   1982  340.86  0.03
# 4   1983  342.53  0.05
# 5   1984  344.07  0.07
# 6   1985  345.54  0.07
# 7   1986  346.97  0.07
# 8   1987  348.68  0.09
# 9   1988  351.16  0.07
# 10  1989  352.78  0.06
# 11  1990  354.05  0.07
# 12  1991  355.39  0.06
# 13  1992  356.09  0.06
# 14  1993  356.83  0.07
# 15  1994  358.33  0.07
# 16  1995  360.17  0.05
# 17  1996  361.93  0.04
# 18  1997  363.05  0.05
# 19  1998  365.70  0.04
# 20  1999  367.80  0.07
# 21  2000  368.96  0.06
# 22  2001  370.57  0.05
# 23  2002  372.59  0.04
# 24  2003  375.15  0.04
# 25  2004  376.95  0.06
# 26  2005  378.98  0.05
# 27  2006  381.15  0.05
# 28  2007  382.90  0.05
# 29  2008  385.02  0.05
# 30  2009  386.50  0.04
# 31  2010  388.76  0.06
# 32  2011  390.63  0.06
# 33  2012  392.65  0.07
# 34  2013  395.40  0.06
# 35  2014  397.34  0.05
# 36  2015  399.65  0.05
# 37  2016  403.06  0.07
# 38  2017  405.22  0.07
# 39  2018  407.61  0.07
# ...

# %%
x= data1['year']
y= data1['mean']
z= data1['unc']

# %%
plt.plot(x,y)

# %%
plt.plot(x,z)

# %%
x = data[['mean']].values
y = data['year']

# %%
model = LinearRegression(fit_intercept = False)

# %%
clf = model.fit(x , y)

# %%
print('Coefficient: ',clf.coef_)
# Out:
# Coefficient:  [5.36232618]

# %%
predictions = model.predict(x)

# %%
print('Coefficient: ',clf.coef_)
print('Y intercept: ',clf.intercept_)
# Out:
# Coefficient:  [5.36232618]
# Y intercept:  0.0

# %%
for i in range(len(predictions[0:5])):
    print('Actual: ',y[i], 'Predicted: ', predictions[i])

# %%
plt.scatter(x,y)
plt.plot(x,predictions,'red')
plt.show()
